# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\Aircraft-Maintenance-Analytics\data\raw\2009.csv",low_memory=False)

# %%
df.head()
# Out:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2009-01-01         XE               1204    DCA  EWR          1100
# 1  2009-01-01         XE               1206    EWR  IAD          1510
# 2  2009-01-01         XE               1207    EWR  DCA          1100
# 3  2009-01-01         XE               1208    DCA  EWR          1240
# 4  2009-01-01         XE               1209    IAD  EWR          1715
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1058.0       -2.0      18.0      1116.0  ...              62.0
# 1    1509.0       -1.0      28.0      1537.0  ...              82.0
# 2    1059.0       -1.0      20.0      1119.0  ...              70.0
# 3    1249.0        9.0      10.0      1259.0  ...              77.0
# 4    1705.0      -10.0      24.0      1729.0  ...             105.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 6429338
# Columns: 28

# %%
df.columns.tolist()
# Out:
# ['FL_DATE',
#  'OP_CARRIER',
#  'OP_CARRIER_FL_NUM',
#  'ORIGIN',
#  'DEST',
#  'CRS_DEP_TIME',
#  'DEP_TIME',
#  'DEP_DELAY',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'CRS_ARR_TIME',
#  'ARR_TIME',
#  'ARR_DELAY',
#  'CANCELLED',
#  'CANCELLATION_CODE',
#  'DIVERTED',
#  'CRS_ELAPSED_TIME',
#  'ACTUAL_ELAPSED_TIME',
#  'AIR_TIME',
#  'DISTANCE',
#  'CARRIER_DELAY',
#  'WEATHER_DELAY',
#  'NAS_DELAY',
#  'SECURITY_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  'Unnamed: 27']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6429338 entries, 0 to 6429337
# Data columns (total 28 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   OP_CARRIER_FL_NUM    int64
#  3   ORIGIN               object
#  4   DEST                 object
#  5   CRS_DEP_TIME         int64
#  6   DEP_TIME             float64
#  7   DEP_DELAY            float64
#  8   TAXI_OUT             float64
#  9   WHEELS_OFF           float64
#  10  WHEELS_ON            float64
#  11  TAXI_IN              float64
#  12  CRS_ARR_TIME         int64
#  13  ARR_TIME             float64
#  14  ARR_DELAY            float64
#  15  CANCELLED            float64
#  16  CANCELLATION_CODE    object
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  AIR_TIME             float64
#  21  DISTANCE             float64
# ...

# %%
missing = (
    df.isnull()
      .sum()
      .sort_values(ascending=False)
)

missing.head(30)
# Out:
# Unnamed: 27            6429338
# CANCELLATION_CODE      6342300
# NAS_DELAY              5258837
# LATE_AIRCRAFT_DELAY    5258837
# SECURITY_DELAY         5258837
# WEATHER_DELAY          5258837
# CARRIER_DELAY          5258837
# ACTUAL_ELAPSED_TIME     102362
# ARR_DELAY               102361
# AIR_TIME                102361
# WHEELS_ON                89322
# ARR_TIME                 89322
# TAXI_IN                  89321
# WHEELS_OFF               85787
# TAXI_OUT                 85787
# DEP_TIME                 82867
# DEP_DELAY                82867
# OP_CARRIER                   0
# FL_DATE                      0
# ORIGIN                       0
# CRS_DEP_TIME                 0
# DEST                         0
# OP_CARRIER_FL_NUM            0
# CANCELLED                    0
# CRS_ELAPSED_TIME             0
# DIVERTED                     0
# CRS_ARR_TIME                 0
# DISTANCE                     0
# dtype: int64

# %%
df.head()
# Out:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2009-01-01         XE               1204    DCA  EWR          1100
# 1  2009-01-01         XE               1206    EWR  IAD          1510
# 2  2009-01-01         XE               1207    EWR  DCA          1100
# 3  2009-01-01         XE               1208    DCA  EWR          1240
# 4  2009-01-01         XE               1209    IAD  EWR          1715
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0    1058.0       -2.0      18.0      1116.0  ...              62.0
# 1    1509.0       -1.0      28.0      1537.0  ...              82.0
# 2    1059.0       -1.0      20.0      1119.0  ...              70.0
# 3    1249.0        9.0      10.0      1259.0  ...              77.0
# 4    1705.0      -10.0      24.0      1729.0  ...             105.0
#
#    ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(510852)

# %% [markdown]
# <h5> Key Findings
#
# - Dataset contains 6,429,338 rows and 28 columns.
# - 510,852 duplicate records identified.
# - Unnamed: 27 is completely empty and will be removed.
# - FL_DATE should be converted to datetime.
# - Delay reason columns have many null values because they are populated only for delayed flights.
# - Cancellation codes are available only for cancelled flights.
# </h5>
